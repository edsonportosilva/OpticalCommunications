# %% [markdown]
# # Importação das bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from IPython.display import display, Math
from IPython.display import display as disp

from IPython.core.display import HTML
from IPython.core.pylabtools import figsize

HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %%
plt.style.use('seaborn-v0_8-talk')

# %% [markdown]
# ## Parâmetros do MZM

# %% [markdown]
# O sinal óptico na saída do MZM é:
#
# \begin{align}
# E_{out}(t) &= \frac{E_{in}(t)}{2}e^{j\phi_1(t)} + \frac{E_{in}(t)}{2}e^{j\phi_2(t)} \\
# &= E_{in}(t)\cos\left( \frac{u(t)}{2V_{\pi}}\pi \right)
# \end{align}
#
# A transmitância, obtida a partir da relação das intensidades de campo elétrico, é:
#
# \begin{equation}
# \frac{\left| E_{out}(t) \right|^2}{\left| E_{in}(t) \right|^2} = \frac{P_{out}(t)}{P_{in}(t)} = \frac{1}{2} + \frac{1}{2} \cos\left( \frac{u(t)}{V_{\pi}}\pi \right)
# \end{equation}

# %%
def MZM(V, Vdc, Vpi):
  return (np.cos(np.pi/2*(V+Vdc)/Vpi))

# %%
Vmax = 2
Vmin = -2
V = np.linspace(Vmin, Vmax, 100)

# %%
Vpi = 1
Vdc = 0

# %%
fig1 = plt.figure()
plt.plot(V, MZM(V, Vdc, Vpi), label = 'Field')
plt.plot(V, np.abs(MZM(V, Vdc, Vpi))**2, label = 'Power')
plt.xlabel(r'$V/V_\pi$')
plt.ylabel('Transmissão')
plt.xlim([Vmin, Vmax])
plt.grid(True)

# %%
Vdc = -Vpi

# %%
plt.plot(V, MZM(V, Vdc, Vpi), linewidth = 2, label = 'Field')
plt.plot(V, np.abs(MZM(V, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel(r'$V/V_\pi$')
plt.ylabel('Transmissão')
plt.xlim([Vmin, Vmax])
plt.grid(True)

# %% [markdown]
# ## Sinal modulante

# %%
# !pip install OptiCommPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting OptiCommPy
#   Downloading OptiCommPy-0.3.0.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 KB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (1.22.4)
# Requirement already satisfied: scipy>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (1.10.1)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (3.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (1.11.1)
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (4.65.0)
# Requirement already satisfied: numba>=0.54.1 in /usr/local/lib/python3.9/dist-packages (from OptiCommPy) (0.56.4)
# Collecting scikit-commpy>=0.7.0
#   Downloading scikit-commpy-0.8.0.tar.gz (102 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.8/102.8 KB 10.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting simple-pid>=1.0.1
#   Downloading simple_pid-1.0.1-py2.py3-none-any.whl (8.1 kB)
# Collecting mpl-scatter-density>=0.7.0
#   Downloading mpl_scatter_density-0.7-py3-none-any.whl (655 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 655.5/655.5 KB 49.7 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (8.4.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (23.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=3.7.0->OptiCommPy) (0.11.0)
# Collecting fast-histogram>=0.3
#   Downloading fast_histogram-0.11-cp36-abi3-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.54.1->OptiCommPy) (67.6.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.54.1->OptiCommPy) (0.39.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->OptiCommPy) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=3.7.0->OptiCommPy) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7.0->OptiCommPy) (1.16.0)
# Building wheels for collected packages: OptiCommPy, scikit-commpy
#   Building wheel for OptiCommPy (setup.py) ... done
#   Created wheel for OptiCommPy: filename=OptiCommPy-0.3.0-py3-none-any.whl size=53864 sha256=70da8319322585ecb4e0d80b6521bda6df43b86bc3390e23582f9f7263cb3363
#   Stored in directory: /root/.cache/pip/wheels/05/80/18/620e275b008cb909f1542eac0222f8f538add190c386aa39e3
#   Building wheel for scikit-commpy (setup.py) ... done
#   Created wheel for scikit-commpy: filename=scikit_commpy-0.8.0-py3-none-any.whl size=115022 sha256=b7f9fb52beeae017372b4c2ac7f8273cdb87422c5612d51fc6d00dc3c1259571
#   Stored in directory: /root/.cache/pip/wheels/68/35/df/fb788af1195ca03415b0c2ec1c84e39cec3225f2b8fd4265b2
# Successfully built OptiCommPy scikit-commpy
# Installing collected packages: simple-pid, fast-histogram, scikit-commpy, mpl-scatter-density, OptiCommPy
# Successfully installed OptiCommPy-0.3.0 fast-histogram-0.11 mpl-scatter-density-0.7 scikit-commpy-0.8.0 simple-pid-1.0.1

# %%
from commpy.utilities  import signal_power, upsample
from optic.dsp import firFilter, pulseShape
from optic.plot import eyediagram

# %%
# parâmetros da simulação
SpS = 32

Rs  = 10e9          # Taxa de símbolos (para o caso do OOK Rs = Rb)
Ts  = 1/Rs          # Período de símbolo em segundos
Fa  = 1/(Ts/SpS)    # Frequência de amostragem do sinal (amostras/segundo)
Ta  = 1/Fa          # Período de amostragem
P0  = 1             # Potência

# %%
# gera sequência de bits pseudo-aleatórios
bits   = np.random.randint(2, size=20)    
n      = np.arange(0, bits.size)
# mapeia bits para símbolos OOK
symbTx = np.sqrt(P0)*bits
# upsampling
symbolsUp = upsample(symbTx, SpS)
# pulso retangular ideal
pulse = pulseShape('rect', SpS)
pulse = pulse/max(abs(pulse))
#formatação de pulso retangular
sigTx  = firFilter(pulse, symbolsUp)
# plota sinal 
t = np.arange(0, sigTx.size)*(Ta/1e-12)
# instantes centrais dos intervalos de sinalização
symbolsUp = upsample(2*bits-1, SpS)
symbolsUp[symbolsUp==0] = np.nan
symbolsUp = (symbolsUp + 1)/2

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
axs[0].stem(symbTx, basefmt=" ", use_line_collection=True)
axs[0].set_xlabel('n')
axs[0].set_ylabel('$b_n$')
axs[0].grid(True)

axs[1].plot(t, sigTx.real,'-', linewidth=3)
axs[1].plot(t, symbolsUp.real, 'o')
axs[1].set_xlabel('Tempo [ps]')
axs[1].set_ylabel('amplitude')
axs[1].grid(True)
# Out:
# <ipython-input-22-b473a3c03a56>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   axs[0].stem(symbTx, basefmt=" ", use_line_collection=True)

# %%
fig1

# %%
Vpi  = 1
Vdc  = 0

# %%
plt.figure(figsize=(9,4))
plt.plot(t, np.abs(MZM(sigTx.real, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel('tempo [ps]')
plt.ylabel('amplitude')
plt.grid(True)

# %%
Vpi  = 1
Vdc  = -Vpi

# %%
plt.plot(V, MZM(V, Vdc, Vpi), linewidth = 2, label = 'Field')
plt.plot(V, np.abs(MZM(V, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel(r'$V/V_\pi$')
plt.ylabel('Transmissão')
plt.xlim([Vmin, Vmax])
plt.grid(True)

# %%
plt.figure(figsize=(9,4))
plt.plot(t, np.abs(MZM(sigTx.real, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel('tempo [ps]')
plt.ylabel('amplitude')
plt.grid(True)

# %%
Vpi  = 1
Vdc  = -Vpi/2

# %%
plt.plot(V, MZM(V, Vdc, Vpi), linewidth = 2, label = 'Field')
plt.plot(V, np.abs(MZM(V, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel(r'$V/V_\pi$')
plt.ylabel('Transmissão')
plt.xlim([Vmin, Vmax])
plt.grid(True)

# %%
plt.figure(figsize=(9,4))
plt.plot(t, np.abs(MZM(sigTx.real, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel('tempo [ps]')
plt.ylabel('amplitude')
plt.grid(True)

# %% [markdown]
# ## Limitação em frequência

# %% [markdown]
# Considere que a resposta do driver ou modulado em frequência é limitado.

# %%
# upsampling
symbolsUp = upsample(symbTx, SpS)
# pulso retangular ideal
pulse = pulseShape('nrz', SpS)
pulse = pulse/max(abs(pulse))
#formatação de pulso retangular
sigTx_nrz  = firFilter(pulse, symbolsUp)
# instantes centrais dos intervalos de sinalização
symbolsUp = upsample(2*bits-1, SpS)
symbolsUp[symbolsUp==0] = np.nan
symbolsUp = (symbolsUp + 1)/2

# %%
fig, axs = plt.subplots(1,2,figsize=(12,6))
axs[0].stem(symbTx, basefmt=" ", use_line_collection=True)
axs[0].set_xlabel('n')
axs[0].set_ylabel('$b_n$')
axs[0].grid(True)

axs[1].plot(t, sigTx_nrz.real,'-', linewidth=3)
axs[1].plot(t, symbolsUp.real, 'o')
axs[1].set_xlabel('tempo [ps]')
axs[1].set_ylabel('amplitude')
axs[1].grid(True)
# Out:
# <ipython-input-38-cb70d464e9bd>:2: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   axs[0].stem(symbTx, basefmt=" ", use_line_collection=True)

# %%
fig1

# %%
Vpi  = 1
Vdc  = -Vpi

# %%
plt.figure(figsize=(9,4))
plt.plot(t, np.abs(MZM(sigTx_nrz.real, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel('tempo [ps]')
plt.ylabel('amplitude')
plt.grid(True)

# %%
Vpi  = 1
Vdc  = -Vpi/2

# %%
plt.figure(figsize=(9,4))
plt.plot(t, np.abs(MZM(sigTx_nrz.real, Vdc, Vpi))**2, linewidth = 2, label = 'Power')
plt.xlabel('tempo [ps]')
plt.ylabel('amplitude')
plt.grid(True)
